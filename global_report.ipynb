# %%
# %%capture
# !pip install pandas openpyxl --dry-run

# %%
import pandas as pd
import xlrd

# %%
# Load Excel file
df = pd.read_excel('2021_Global_Nutrition_Report_Dataset_6YAamkd.xlsx', engine='openpyxl', sheet_name = None)
df
# Out:
# {'Introduction':    Unnamed: 0 2021 Global Nutrition Report: The state of global nutrition
#  0         NaN                          globalnutritionreport.org
#  1         NaN                                                NaN
#  2         NaN  For full definitions and sources, see the 2021...         ,
#  'Indicator descriptions':                    section                            variable
#  0                 Overview                       anaemia_track  \
#  1                 Overview                           lbw_track
#  2                 Overview                           ebf_track
#  3                 Overview              under_5_stunting_track
#  4                 Overview               under_5_wasting_track
#  ..                     ...                                 ...
#  122  Environmental impacts          planetary_impacts_Cropland
#  123  Environmental impacts        planetary_impacts_Freshwater
#  124  Environmental impacts  planetary_impacts_Greenhouse gases
# ...

# %%
sheet_lengths = {}

# Iterate over the output above and calculate the length of each DataFrame
for sheet_name, df in df.items():
    sheet_lengths[sheet_name] = len(df)

# Print the lengths of each sheet
print(sheet_lengths)
# Out:
# {'Introduction': 3, 'Indicator descriptions': 127, 'Country overview': 194, 'Region overview': 29, 'Country child nutrition': 5178, 'Region child nutrition': 51, 'Country IYCF': 2775, 'Region IYCF': 25, 'Country adolescent': 762, 'Region adolescent': 116, 'Country adult': 4268, 'Region adult': 427, 'Country dietary needs': 193, 'Region dietary needs': 30, 'Country intervention': 1793, 'Country determinants': 194, 'Region determinants': 29, 'Country resources': 194, 'Region resources': 29, 'Country policy': 194, 'Region policy': 29, 'Country economics': 773, 'Region economics': 69, 'Country environment': 2157, 'Region environment': 351}
